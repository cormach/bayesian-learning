# %%
import arviz as az
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pymc as pm
import pytensor as pt

# %%
index_data = pd.read_csv("./data/Index.csv")
index_data.head()
# Out:
#          Date   Index
# 0  02/01/2008  6416.7
# 1  03/01/2008  6479.4
# 2  04/01/2008  6348.5
# 3  07/01/2008  6335.7
# 4  08/01/2008  6356.5
